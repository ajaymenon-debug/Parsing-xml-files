# %% [markdown]
# ## Table of Contents
#
# * [1. Extracting the data](#one)
# * [2. Using Regex to extract tweet, id and date](#two)
#     * [2.1 Tweet](#two1)
#     * [2.2 ID](#two2)
#     * [2.3 Date](#two3)
# * [3. Striping and making the tweets in proper format ](#three)
# * [4. Creating a dictionary with ID and tweets ](#four)
# * [5. Convert special characters to HTML Code ](#five)
# * [6. Use surrogate pairs to get the emojis](#six)
# * [7. Using langid to remove non - english tweets](#seven)
# * [8. Writing to XML](#eight)
# * [Converting to dict from XML](#nine)
# * [Summary](#sum)
#
#
# ### 1.  Extracting the data <a class="anchor" name="one"></a>
#
# Here the first step of the task is the extract all the text file from the folder 30511704 ( My student ID).
#
# Here I have used the package os and using the funtion scandir, I can pass the basepath where all my files are present and extract the data.
#
# First I initialize the variable 'final'  where I append the extrire content of all the text files. After the execution of this cell, the variable 'final' will have the raw data extracted from all the text files.

# %%
import re
import os

# %%
basepath = "./data/"
files = []

final = " "
with os.scandir(basepath) as entries:
    for entry in entries:
        if entry.is_file():
            files.append(entry.name)
            
for index in files:
    name = "{index}".format(index=index)
    path = os.path.join(basepath, name)
    with open(path, mode="r", encoding="utf-8") as fd:
        content = fd.read()
        final += content

# %%
len(files)
# Out:
# 2421

# %% [markdown]
# ### 2. Using Regex to extract tweet, id and date <a class="anchor" name="two"></a>
#
# Next step is to extract tweet, id and date using regular expression
#
# #### 2.1 Tweets <a class="anchor" name="two1"></a>
#
# The regex used to extract the tweets is "text":(.*?)(?:"id":|"created_at":|"errors":)
#
# This regex and the split into 3 parts.
#
# First part is the starting of the tweet. All the text tweets start with "text": .So thats why I have given "text": as the starting of the regex and this is a non-capture subpattern
#
# Second part is the actual tweet text. This can be of any characters and no. of charecters can be 0 or more than 0. So I have made this part as (.*?) . This part has the captured subpattern.
#
#
# The third part is the ending of the tweet. Here I have used the starting of the next tweet to get the ending of the current tweet. I have noticed that all the tweets start with either  "id": or "created_at": or "errors":. So just after the ending of each tweet text it can be id": or "created_at": or "errors":. So I have given (?:"id":|"created_at":|"errors":) in the regex. The part is a non-capturing subpattern and so I have given ?: at the starting of this part
#
# Most of the tweets start with "created_at":. for eg. tweet id: 1258367433028636677 ( In the sample file)
#
# After some tweets there might be a error tag. For eg. tweet id: 1258367433322237952 ( In the sample file)
#
# #### 2.2 ID <a class="anchor" name="two2"></a>
#
# The regex used to extract the ID is "id":"([0-9]+)"
#
# eg. "id":"1258367433322237952"
#
# The ID start with the tag "id":" and after that it will be a set of numbers. It can 1 or more than 1 digits. So I have given "id":"([0-9]+)". Here "id":" is a non capturing group and the capturing group is the digit ([0-9]+)
#
#
# #### 2.3 Date <a class="anchor" name="two3"></a>
#
#
# The regex used to extract the Date is "created_at":"(\d{4}-\d{2}-\d{2})(?:.*?)"
#
# eg. "created_at":"2020-05-07T12:05:50.000Z"
#
# Each date field start with the tag "created_at":". This is part is a non-capturing subpattern.
#
# After the first tag, then the date will be present in the format (\d{4}-\d{2}-\d{2}). This has to be made as capturing group.
#
# After this date, there is a time which needs to be ignored and end with "

# %%
date = re.findall(r'(\d{4}-\d{2}-\d{2})', final)

_id = re.findall(r'"id":"([0-9]+)"', final)
uniq_id = list(set(_id))
tweet = re.findall(r'"text":(.*?)(?:"id":|"created_at":|"errors":)', final,re.DOTALL)
#tweet = re.findall(r'(?:"text":")(.*?)(?:"},{"created_at")', final)
created = re.findall(r'"created_at":"(\d{4}-\d{2}-\d{2})(?:.*?)"', final)
uniq_date = list(set(created))

# %% [markdown]
# ### 3. Striping and making the tweets in proper format <a class="anchor" name="three"></a>
#
# Next step is the remove the unwanted characters from the tweet and just have the tweet text alone. ( This could have handled in regex itself, but I tried with this method.
#
# Here I strip of the characters ,{}]" which is present at the staring and ending of the tweet

# %%
tweet =[ x.strip(',{}]') for x in tweet]

for i in range(len(tweet)):
    tweet[i] = tweet[i].strip('"')

# %% [markdown]
# ### 4 Creating a dictionary with ID and tweets  <a class="anchor" name="four"></a>
#
# Now we have 3 lists each with tweets, ID and Date.
#
# For the future processing I combine the tweets and ID list into a single dictionary to make the processing easier

# %%
res = dict(zip(_id, tweet))

# %% [markdown]
# ### 5. Convert special characters to HTML Code <a class="anchor" name="five"></a>
#
# Here we need to convert few of the special characters to HTML Code inorder to make it compatible for XML format
#
# & , ' , " , > , <
#
# These 5 characters needs to be converted.
#
# There are some tweets in which \n is given. This needs to be converted to \\n so that the system can read it.
#
# Also, there were some tweets in which \ is given. This needs to be converted to \\ so that the system can read it.

# %%
for key, val in res.items(): 
    t = val.replace("&","&amp;").replace("'", "&apos;").replace('\\"',"&quot;").replace(">","&gt;").replace("<","&lt;").replace("\\","\\\\").replace("\n","\\n")
    res[key] = t

# %% [markdown]
# Since we are converting \\ to \\\\, \\ u will be converted to \\\\u and so this need to be converted back to its orginal form to use the surrogate pass

# %%
for key, val in res.items(): 
    t = val.replace("\\\\u","\\u")
    res[key] = t

# %% [markdown]
# ### 6. Use surrogate pairs to get the emojis <a class="anchor" name="six"></a>
#
# Next step is to get the emojis or formula which are encoded with 'surrogate pairs'.
#
# For this we have to encode this with surrogatepass and then decode to the form which we want.
#
# Here we do this encoding and decoding only if there exist any word with the pattern \\uD

# %%
for key, val in res.items(): 
    if (re.findall(r'\\uD', val)) != []:
        t = eval("'" + val + "'").encode('utf-16', 'surrogatepass').decode('utf-16')
    else:
        t = val
    res[key] = t

# %% [markdown]
# Since we are converting \\ to \\\\, \\ n will be converted to \\\\n and so this need to be converted back to its orginal form to \\n

# %%
# Replace // with /
for key, val in res.items(): 
    t = val.replace("\\\\n","\\n")
    res[key] = t

# %% [markdown]
# ### 7. Using langid to remove non - english tweets <a class="anchor" name="seven"></a>
#
# Next step is to remove the tweets which are not in english
#
# For this, we using langid package to use the classify function to check if the tweet is in english.
#
# We remove the tweets which are not in english

# %%
import langid

# %%
delete = [] 
for key, val in res.items(): 
    if langid.classify(str(val))[0]!= 'en': 
        delete.append(key)
for i in delete: 
    del res[i]

# %% [markdown]
# Now since all the processing is completed, now I convert our final dictionary to 2 seperate lists to write it to the XML file

# %%
_id = []
tweet = []
for i,j in res.items(): 
    _id.append(i) 
    tweet.append(j)

# %% [markdown]
# Here  _id and tweet are 2 lists which are having the values after all the processing

# %% [markdown]
# ### 8. Writing to XML <a class="anchor" name="eight"></a>
#
# The final step is to write the id and tweets collected to XML files.
#
# First we open a file  - 30511704.xml to write our tweets and ID
#
# Next we write the header to this xml File

# %%
header = "<?xml version=\"1.0\" encoding=\"UTF-8\"?>\n<data>\n"
output = open("30511704.xml", mode="w", encoding="utf-8")

# %%
for each in header:
    output.write(each)

# %% [markdown]
# Next we write the id and tweets according to format of the sample xml file.

# %%
for i in range(len(uniq_date)):
    output.write("<tweets date=\""+ uniq_date[i] + "\">\n")
    for j in range(len(_id)):  
        if (date[j] == uniq_date[i]):
            output.write("<tweet id=\"" + _id[j] +"\">" +  tweet[j].replace("\\n","\n")+ "</tweet>\n")
    output.write("</tweets>\n")
output.write("</data>")
output.close()

# %% [markdown]
# ### Converting to dict from XML <a class="anchor" name="nine"></a>
#
# This part is to test if the XML created is correct and readable.

# %%
import xmltodict
with open('30511704.xml','r') as infile:
    text = infile.read()

# %%
import xmltodict
final_dic = xmltodict.parse(text)

# %%
final_lis = []
final_lis = (final_dic['data']['tweets']['@date'== '2020-06-07']['tweet'])

# %%
final_lis
# Out:
# [OrderedDict([('@id', '1244612928990588929'),
#               ('#text',
#                "@paddymacc1 People need to learn from  this sad  realities, if not  careful many countries will plunge into  the  same ditch. Covid-19 is real &amp; traumatizing  families. Don't add yours on this list.")]),
#  OrderedDict([('@id', '1244612929229590529'),
#               ('#text',
#                '(City A.M):#Michael Gove overstates #UK Covid-19 testing as government misses target : Senior government minister Michael Gove has been caught out misstating the number of coronavirus tests carried out last week. The The post .. https://t.co/XMcbDdUpF9 https://t.co/1sagt5ryr3')]),
#  OrderedDict([('@id', '1244612929800015872'),
#               ('#text',
#                'Six response plan guidelines for navigating Covid-19 https://t.co/8PGsomHtVF')]),
#  OrderedDict([('@id', '1244612929833615364'),
#               ('#text',
#                "Trump Cabinet's Bible teacher says gays cause 'God's wrath' in COVID-19 blog post https://t.co/v0MuCky0PZ")]),
#  OrderedDict([('@id', '1244612932828196864'),
#               ('#text',
#                'Mantep iki #wastafel #CoronaVirusIndonesia #COVID19 #Coronavirustruth https://t.co/0xH4hPbEXY')]),
#  OrderedDict([('@id', '1244612932870328320'),
#               ('#text',
#                'It would be very easy to stay open but we have a duty of care to our employees and a total respect for our NHS and those who put their lives at risk to stop this pandemic\n#staysafe #StayHomeSaveLives #livesbeforeprofit #haldaneuk https://t.co/dYrXFhl0nH')]),
#  OrderedDict([('@id', '1244612932891226122'),
#               ('#text',
#                'Drakes baby is white enough to play the game the “right way” #COVID2019  #coronavirus #Coronavirustruth #COVID #dontdiebeforethepodcast #drake #baby #BabySharkHandWashChallenge')]),
#  OrderedDict([('@id', '1244612933063188481'),
#               ('#text',
#                'We need to do more, some things we can do NOW are in my latest White Paper (Govt Report)\nhttps://t.co/GJ1p51i9zO\n#cdnpoli #canadalockdown #CanadaCovid19 #COVID19  #COVID19ON https://t.co/xC0toNHblC')]),
#  OrderedDict([('@id', '1244612933163913218'),
#               ('#text',
#                '@p_surendran Hi sir, you will be able to check all the information on this page of our website: https://t.co/yMD2IoqHTO\n\nLet me know if you have any more specific questions!\nhttps://t.co/XMI1ovTIg2')]),
#  OrderedDict([('@id', '1244612933432143873'),
#               ('#text',
#                '@bl98 Thank you Benoit! \n\nPlease check out my #blog post, "My fellow Americans: we can\'t let Corporate America fyrefestival our nation\'s response to coronavirus." \n\nhttps://t.co/s6kHiD89bM')]),
#  OrderedDict([('@id', '1244612933482659841'),
#               ('#text',
#                'It is not lost on me that had @realDonaldTrump just contracted the virus weeks ago, many fewer people would have died. \n\n#COVID19 \n#AmericanVirus')]),
#  OrderedDict([('@id', '1244612933574893575'),
#               ('#text',
#                'Coronavirus update, March 29:\n\n- U.S. reached 140,000 cases\n- Spain reached 80,000 cases\n- Germany reached 60,000 cases\n- France reached 40,000 cases\n- Netherlands reached 10,000 cases\n- Belgium reached 10,000 cases\n- World reached 700,000 cases')]),
#  OrderedDict([('@id', '1244612937081335810'),
#               ('#text', 'DEFIANT! https://t.co/AwLKNJYbyn')]),
#  OrderedDict([('@id', '1244612937194455041'),
#               ('#text',
#                'Please be positive #COVID19 for him.\nPlease be positive #COVID19 for him.\nPlease be positive #COVID19 for him.\nPlease be positive #COVID19 for him.\nPlease be positive #COVID19 for him.\nPlease be positive #COVID19 for him. https://t.co/BOGf3Ayf4j')]),
#  OrderedDict([('@id', '1244612937433731083'),
#               ('#text',
#                'Billionaire businesswoman Folorunsho Alakija pledges N1bn to support FG’s fight against coronavirus https://t.co/pCaxepTiWz https://t.co/Fr48R40Be2')]),
#  OrderedDict([('@id', '1244612937576153088'),
#               ('#text',
#                'What is the @ArvindKejriwal govt. doing? First the migrant labourers issue. Now this. https://t.co/zUCfEIgqkF')]),
#  OrderedDict([('@id', '1244612937848946689'),
#               ('#text',
#                'The FDA has approved chloroquine and hydroxychloroquine for treatment.  It is neither a miracle drug nor totally ineffectual or untested as many countries are using it for #COVID19 .  Shame on all who are politicizing medicine.\n\nhttps://t.co/mfG3e9q61F')]),
#  OrderedDict([('@id', '1244612937903374339'),
#               ('#text',
#                "Don't miss the next in the Coronavirus webinar series!\nhttps://t.co/2NKTwnIBWe")]),
#  OrderedDict([('@id', '1244612941422497794'),
#               ('#text',
#                'Times like these show us the true nature of the people and organizations around us. Our friends at @TeamAffect are offering their expertise, free of charge, to companies w/ crisis comms needs related to COVID19. Contact them at info@affect.com. https://t.co/GlcnznAjFT')]),
#  OrderedDict([('@id', '1244612941565091841'),
#               ('#text',
#                '#Florida #coronavirusdeath https://t.co/UXyBfs0SdC\n\n( Sent from WFLA News )')]),
#  OrderedDict([('@id', '1244612941577687042'),
#               ('#text',
#                'Trump: Coronavirus-fighting supplies have landed at JFK ~ https://t.co/qP296Ix3kw')]),
#  OrderedDict([('@id', '1244612941661560832'),
#               ('#text', 'https://t.co/teWl2t9VZ9')]),
#  OrderedDict([('@id', '1244612941673947141'),
#               ('#text',
#                '‘Pajama entertainment,’ the newest cultural shift of the coronavirus era\nhttps://t.co/F9jj0alPgQ')]),
#  OrderedDict([('@id', '1244612941883768837'),
#               ('#text',
#                'I had a dream that coronavirus was over and all the bars reopened and frizzys was charging a $269 cover to get in')]),
#  OrderedDict([('@id', '1244612942068355073'),
#               ('#text', '‘This Is Dealing with Coronavirus')]),
#  OrderedDict([('@id', '1244612945507737601'),
#               ('#text',
#                'Coronavirus US live: Trump rants at Pelosi and other politicians as deaths climb past 2,500 https://t.co/cQbsrwud1p')]),
#  OrderedDict([('@id', '1244612945872486400'),
#               ('#text',
#                '@itsJeffTiedrich @realDonaldTrump Well this is the  same bloated clown who was going about ratings during a covid19 press conference yesterday.')]),
#  OrderedDict([('@id', '1244612946514378758'),
#               ('#text',
#                'Auto Industry Reacts to Coronavirus Threat (yes, GM is producing ventilators and making masks) -- https://t.co/w28aOonJd3')]),
#  OrderedDict([('@id', '1244612949572018181'),
#               ('#text',
#                "@kupaank I'm a developer looking for a job since the coronavirus took my job, if you could give my portfolio a look, and maybe even retweet this that would be greatly appreciated! &lt;3 https://t.co/GAr19J13Wn [79]")]),
#  OrderedDict([('@id', '1244612949848793088'),
#               ('#text',
#                'Love this guide for children from the @ChildrensComm :)\nhttps://t.co/KsxzmIAPTY')]),
#  OrderedDict([('@id', '1244612950456807429'),
#               ('#text',
#                'Louder!!!!!\n\nPhilanthropist: Yes\nSenator: NO!!!! https://t.co/pjUwHQdgcI')]),
#  OrderedDict([('@id', '1244612950528147463'),
#               ('#text',
#                'Past outbreaks like Ebola, SARS, and Nipah show caregiving girls &amp; women were impacted in high numbers. @WomenDeliver calls on policymakers &amp; governments to address how traditional gender roles affect vulnerability to #COVID19: https://t.co/R4CkNmnE2q')]),
#  OrderedDict([('@id', '1244612950587031556'),
#               ('#text',
#                '61 doctors died for #coronavirus in Italy according to the Italian press @cnnbrk @Telegraph this is so sad. I bet US and UK will be next 😢')]),
#  OrderedDict([('@id', '1244612954294611974'),
#               ('#text',
#                '@achanzeggie what’s your comment now 😂😂 https://t.co/jQ1jsyMLCZ')]),
#  OrderedDict([('@id', '1244612954449903617'),
#               ('#text',
#                "Great news! The FDA tends to be overly cautious, but when people are dying b/c they can't breathe, you bring out whatever you've got that could help. This drug has already many coronavirus victims' lives. Let's get it out there! https://t.co/Hcy0nh7Zhc")]),
#  OrderedDict([('@id', '1244612954584162306'),
#               ('#text',
#                '@actormanojjoshi I request you to make a mandatory rule that after 14 days of home quarantine there should be a check up of people living in quarantine specially coming from abroad so that later on we don’t face any problem if they have coronavirus without symptoms as we have seen it')]),
#  OrderedDict([('@id', '1244612954613481472'),
#               ('#text',
#                'This is a bill that I would support when elected to the state Senate. https://t.co/ejFPGpSDu9')]),
#  OrderedDict([('@id', '1244612954705858569'),
#               ('#text',
#                'NewsNow: Why coronavirus could mean weather forecasts are less accurate https://t.co/Gnfkyvh4EG')]),
#  OrderedDict([('@id', '1244612958157766656'),
#               ('#text', 'https://t.co/mSDE5ESFWR https://t.co/LYleO09nC2')]),
#  OrderedDict([('@id', '1244612958271004677'),
#               ('#text',
#                'How creative they must think we are to have staged the entire world to show hospitals with people dying of a "hoax".  To have coordinated every country in the world to report #\'s of a "hoax" disease. To stage films of bodies being put on trucks. Damn we\'re amazing. Stupid people! https://t.co/X25SUkFZTI')]),
#  OrderedDict([('@id', '1244612958367383552'),
#               ('#text',
#                'Hope she gets better and it has nothing to do with politics https://t.co/ddynWYwxHt')]),
#  OrderedDict([('@id', '1244612958535086082'),
#               ('#text',
#                '@G_Jyoti10 Supreme Court had asked chief secretaries of all states to respond by March 20 with measures to curb overcrowding in jails amidst the COVID-19 outbreak and prisoners are being released from all states. We demand to #ReleaseAsharamjiBapuOnParole . https://t.co/kaCA3dHIuy')]),
#  OrderedDict([('@id', '1247011732813279232'),
#               ('#text', 'Lies kill https://t.co/MjXC4FhEqZ')]),
#  OrderedDict([('@id', '1247011735745310720'),
#               ('#text',
#                'Coronavirus lockdown clears Paris pollution, brings birdsong and clear views https://t.co/BUC2Cc91OT')]),
#  OrderedDict([('@id', '1247011735787188224'),
#               ('#text',
#                '@EggerDC I mean......it probably won’t give you a Coronavirus.')]),
#  OrderedDict([('@id', '1247011736831406087'),
#               ('#text',
#                "Is it only Jesus' blood that protects from coronavirus or can I cover myself with anybody's blood")]),
#  OrderedDict([('@id', '1247011739490758656'),
#               ('#text',
#                'Within China the criteria for indicating a patient is #COVID19 negative are very stringent.\n\nWithin Australia we have not adopted these stringent criteria to our detriment. https://t.co/Y6wsOCdzH2\n#COVID19 https://t.co/ZCtZi7TxAm')]),
#  OrderedDict([('@id', '1247011739604004864'),
#               ('#text',
#                'This is getting out of hand. The CDC has too much control @realDonaldTrump! We need to take our lives back!! https://t.co/H69dlXgwMc')]),
#  OrderedDict([('@id', '1247011739796996097'),
#               ('#text',
#                'South African workers locked in Chinese-owned factory, forced to make medical masks for coronavirus outbreak, official says\n\nhttps://t.co/oVt3ubI532')]),
#  OrderedDict([('@id', '1247011739910078466'),
#               ('#text',
#                'A 65% increase in "flu" deaths. https://t.co/8gRsaUcqEb')]),
#  OrderedDict([('@id', '1247011740170235905'),
#               ('#text',
#                '@AnnCoulter @realDonaldTrump https://t.co/PrNhRMEHs5')]),
#  OrderedDict([('@id', '1247011740203745280'),
#               ('#text',
#                '@emrazz And also...drugs are not benign. There is a black box warning on that drug. So Trump claiming "what could you lose?" This happened to me. \nhttps://t.co/E3vg2SEDGB')]),
#  OrderedDict([('@id', '1247011740216365056'),
#               ('#text',
#                'There Are At Least 75,000 Coronavirus Infections In India TODAY: 21 Days Not Enough https://t.co/tUZSy1Jgra')]),
#  OrderedDict([('@id', '1247011740438523907'),
#               ('#text',
#                'Watch live: Jacinda Ardern gives update on Covid-19 national response https://t.co/qd9cSkiyFK')]),
#  OrderedDict([('@id', '1247011740686020608'),
#               ('#text', 'Coronavirus update https://t.co/DN2RLyrQLR')]),
#  OrderedDict([('@id', '1247011744196833285'),
#               ('#text', 'Me muero! https://t.co/BMPzSbLkyA')]),
#  OrderedDict([('@id', '1247011744712732672'),
#               ('#text',
#                'French Football Club Doctor “Commits Suicide” After Coronavirus Diagnosis: Report https://t.co/LnUGM72BCT https://t.co/Fded9ynu6H')]),
#  OrderedDict([('@id', '1247011744846761984'),
#               ('#text',
#                'Approximately 45,500 Urns in Wuhan alone. I guess it’s true #ChinaLiedPeopleDied \n\nhttps://t.co/jrYM2awwYt')]),
#  OrderedDict([('@id', '1247011744859303936'),
#               ('#text',
#                'Trump says US stockpiling hydroxychloroquine, which is not yet an FDA-approved COVID-19 treatment  https://t.co/lCiZVslLH1')]),
#  OrderedDict([('@id', '1247011745266380802'),
#               ('#text',
#                'Apparently, they have now backed down on that demand and have said they will meet any costs and bear any losses. https://t.co/uZCqeUYisJ')]),
#  OrderedDict([('@id', '1247011745354268673'),
#               ('#text',
#                "In case you're wondering what old FOX News addicts (like my dad) think re: #coronavirus :\n\nIt was developed by the Chinese government, unleashed on America to hurt Trump and help Biden.\n\nAnd Nancy Pelosi didn't know at first, but Chinese govt contacted her in February and...")]),
#  OrderedDict([('@id', '1247011747736596484'),
#               ('#text',
#                'And you thought #COVID19 is catastrophic, #ClimateChange is far more threatening and closer than you think. Coronavirus is a rehearsal for coming crises, how do think govts are doing?  https://t.co/4kyMtBeV2y via @ConversationEDU')]),
#  OrderedDict([('@id', '1247011747870822401'),
#               ('#text',
#                '#BanTablighiJamaat\nShia leaders demand national ban on Tablighi Jamaat after spike in coronavirus cases https://t.co/fs3slr2mFr')]),
#  OrderedDict([('@id', '1247011747971698689'),
#               ('#text',
#                '@jaketapper https://t.co/ss403mN2wu https://t.co/Mm48pnjR9x')]),
#  OrderedDict([('@id', '1247011748298752001'),
#               ('#text',
#                'Indeed!\n#TrumpIsALoser. And a criminal. https://t.co/BURKiom7T7')]),
#  OrderedDict([('@id', '1247011748307251205'),
#               ('#text',
#                '4. VirusMath: Tell me WHAT Covid-19 is telling you about our vulnerabilities, and what we need to learn Biologically, Socially, Politically, Economically, Technologically, Philosophically, &amp; Mentally. I will COMPILE, SHARE, &amp; COMMENT. (Thanks Bon Jovi: "I’m doing what I can." https://t.co/yvw3x9i4DS')]),
#  OrderedDict([('@id', '1247011749452267520'),
#               ('#text', '@redditindia https://t.co/Y2iOhxkvwz')]),
#  OrderedDict([('@id', '1247011749557088258'),
#               ('#text',
#                'We will be with our friends and family again -  I take comfort in that - we will succeed https://t.co/S5Dh9PGIUD')]),
#  OrderedDict([('@id', '1247011752736206849'),
#               ('#text',
#                'New York Hospital Discharges Outpace New Admissions for 4th Straight Day\n\nhttps://t.co/9EClaZ09yB\n\nDownload The Epoch Times app to see our exclusive Coronavirus coverage and daily updates:https://t.co/dAaXSpVFMJ')]),
#  OrderedDict([('@id', '1247011752799338497'),
#               ('#text',
#                '@foxandfriends @seanhannity @IngrahamAngle @TuckerCarlson @MariaBartiromo @LouDobbs @JudgeJeanine  At least one of you is claiming there is an over-count, but the opposite is true. ANY PETTY TRICK to get Trump RE-ELECTED! Right? https://t.co/tHtCOgp8nC')]),
#  OrderedDict([('@id', '1247011752879034370'),
#               ('#text',
#                'Good Morning 😊 @advmonikaarora Ji Protective measures against coronavirus: Wash your hands with soap and water frequently or use alcohol based hand rub, Avoid touching your eyes, nose &amp; mouth')]),
#  OrderedDict([('@id', '1247011753134665728'),
#               ('#text',
#                "Doctors and Hospitals that don't administer #Hydroxychloroquine, without showing some conflict between medications and yourself, should be sued. https://t.co/9NZbKDYa5Z")]),
#  OrderedDict([('@id', '1247011753327620096'),
#               ('#text',
#                "Donny- Leave the medical to the scientists. No one trusts you, most of America loathes you, and everyone now understands you lie continually. So leave the pills alone sparky. Don't try to be a hero, cuz you're a zero. @realDonaldTrump https://t.co/8AplqpfZZn")]),
#  OrderedDict([('@id', '1247011753931800577'),
#               ('#text',
#                'Haryana: Students of classes 1-8 to be promoted without exams due to COVID-19 lockdown: CM Khattar https://t.co/t3PurP6vqr')]),
#  OrderedDict([('@id', '1247011756095856640'),
#               ('#text',
#                'Europe catches its breath as #coronavirus seems to abate: https://t.co/kIZR0oNapK\nItaly: lowest death toll since March 19\nSpain: continuous fall in confirmed cases\nBelgium: more cured cases than hospitalized ones\nBritain: The Queen delivers rare speech to encourage Britons https://t.co/lRpj5x5su3')]),
#  OrderedDict([('@id', '1247011756259471360'),
#               ('#text',
#                '$CCL - Carnival expects coronavirus to cost $1bn per month - https://t.co/4IN1jpSrNv')]),
#  OrderedDict([('@id', '1247011756402044929'),
#               ('#text', '@DroneOn1 https://t.co/nrAN1lQM6y')]),
#  OrderedDict([('@id', '1247011757194989576'),
#               ('#text',
#                'How US ‘Wasted’ Precious Months Before Preparing for Covid-19 as Trump Predicted ‘a Very Good Ending’ https://t.co/KByHJwfz2S https://t.co/fRFWMOjKnr')]),
#  OrderedDict([('@id', '1247011757274599427'),
#               ('#text',
#                'Sincere request @jeffBezos @JayCarney @DavidZapolsky Spend a week working in high contact warehouses roles doing the same "essential employee" work. Observe by personal experience if current warehouse setup is safe during a #coronavirus pandemic #ProtectAmazonWorkers #ChrisSmall https://t.co/p9l7DhpEp5')]),
#  OrderedDict([('@id', '1247011760172867585'),
#               ('#text',
#                '@EricAle68357361 @i_am_dunwifit For every sell on the bid there is a buyer.... $100,000 worth of $NSPX sucked up in a matter of minutes at the close on Friday... in 2 trades!! One ask slap and one bid sitter... \n\n#Covid19')]),
#  OrderedDict([('@id', '1247011760269385728'),
#               ('#text',
#                "@fran_chambers You don't have common sense, you obviously have a stake in the company that makes this drug. DO NOT take this drug, it has not shown conclusive proof that it works against COVID-19 &amp; could be deadly if you have underlying heart problems.")]),
#  OrderedDict([('@id', '1247011762282651648'),
#               ('#text',
#                "Congratulations, Mr. Governor, it's nice to have you back. https://t.co/UPRUvNn03G")]),
#  OrderedDict([('@id', '1247011762416713728'),
#               ('#text',
#                "@RepMaxineWaters You should be ashamed! Stop pointing fingers &amp; get to work!\nPresident Trump is working for free. He donated his wages to fight the coronavirus. Maybe you should do the same. What have you done to help us? Name one thing, because I can't find anything.")]),
#  OrderedDict([('@id', '1247011764195037184'),
#               ('#text',
#                '8 more people test positive for #Coronavirus in Rajasthan - 5 in Jhunjhunu, 2 in Dungarpur &amp; 1 in Kota. The 5 people in Jhunjhunu and 1 in Dungarpur had attended Tablighi Jamaat event in Delhi. The total number of positive cases in the state increased to 274:Rajasthan Health Dept https://t.co/MCeBobwIDq')]),
#  OrderedDict([('@id', '1247011764765478914'),
#               ('#text',
#                "Of all the Tell All Books that will come out of this administration, Dr Fauci's will be the best https://t.co/SCfC5fH1Rx")]),
#  OrderedDict([('@id', '1247011764912472064'),
#               ('#text',
#                'The COVID-19 lockdowns have resulted in thousands of Americans being stranded abroad https://t.co/H4CIcIyDs9')]),
#  OrderedDict([('@id', '1247011764920713218'),
#               ('#text',
#                "Let's get access to any news / information on the COVID-19 disease at Cambridge University Press Database. Feel free to access https://t.co/k3LgdEWilf for your own perusal. You may also acquire scientific information on respiratory viruses for free. https://t.co/lT2J7HsEK0")]),
#  OrderedDict([('@id', '1247011765071855616'),
#               ('#text',
#                "@CHirth88 I can't wait for this to be our reality one day ❤️❤️❤️ https://t.co/8PKRDmFT83")]),
#  OrderedDict([('@id', '1247011765214380032'),
#               ('#text',
#                'This dude is going to hell. https://t.co/qwONoF2kd9')]),
#  OrderedDict([('@id', '1247011765386383360'),
#               ('#text',
#                'Does this mean the disease can hide in an animal reservoir and reinfect people again? Could this happen with house cats? Will this mean vaccination is the only way to control this disease?\n@WHO #coronavirus #tiger #vaccine https://t.co/dbTasGopXR')]),
#  OrderedDict([('@id', '1247011768871858181'),
#               ('#text',
#                'Definitely a difference between dying of covid-19 and dying of stupidity https://t.co/A45MJ6qNms')]),
#  OrderedDict([('@id', '1246779082299375616'),
#               ('#text',
#                "@Arron_banks Cancer etc is terrible but it doesn't kill doctors, nurses, carers, bus drivers etc in the numbers that the coronavirus is doing through human transmission. The healthcare system would be decimated and then many people with treatable conditions will also die.")]),
#  OrderedDict([('@id', '1246779082521686017'),
#               ('#text',
#                'Wake Up Kids. My job was to cover the #CoronavirusPandemic, until I became part of it. \nhttps://t.co/3QvCg4cbAx')]),
#  OrderedDict([('@id', '1246779085914812417'),
#               ('#text',
#                'The government get criticised for not ordering a lockdown sooner, now they’re getting criticised for not letting people #sunbathe. The levels of hypocrisy baffles me.Half of the fuckers doing it have #StayHomeSaveLives profile pictures. Christ on a bike!!! #COVID2019 #coronavirus')]),
#  OrderedDict([('@id', '1246779086091010050'),
#               ('#text',
#                'Not sure yet but lots of people already thinking about it.\n@danlewer @rob_aldridge @CCIH_Health \n@DocNig https://t.co/jDvVKojGOP')]),
#  OrderedDict([('@id', '1246779089689751553'),
#               ('#text',
#                '@SkyNews @SkyNewsBreak @BBCBreaking @BBCNews \n\nDear MSMs,\n\nI have a crazy idea why not put some stories about survivors and some positive stuff about #coronavirus #Covid_19 on rather than constant doom and gloom.\n\nGive people some hope rather than try and bury them with fear FFS')]),
#  OrderedDict([('@id', '1246779090541121538'),
#               ('#text',
#                "😭💕\n\nFlorida firefighter hospitalized with coronavirus gets surprise at window from colleagues, says 'this is love'\n\nhttps://t.co/VD61bRtlgU")]),
#  OrderedDict([('@id', '1246779090696384517'),
#               ('#text',
#                "The British public can't be trusted to have nice things like exercise 😑 https://t.co/wj6idcUkbH")]),
#  OrderedDict([('@id', '1246779091145154560'),
#               ('#text',
#                'Coronavirus lockdowns are making the working day longer for many. https://t.co/xmv92EHHAX')]),
#  OrderedDict([('@id', '1246779093800095745'),
#               ('#text',
#                'In my little town in Transylvania they chlorine the streets. Here? Nothing! Just yellow tape around the playground equipment and shittons of gloves everywhere . #shame https://t.co/FqFwD1z0QA')]),
#  OrderedDict([('@id', '1246779094546755584'),
#               ('#text',
#                "Lots of people out today seem to be struggling with the concept of solo riding. \n\nBBC News - Coronavirus: Exercise out of the home 'could be banned' if people flout rules https://t.co/WZmiBNdwLy")]),
#  OrderedDict([('@id', '1246779094811004928'),
#               ('#text',
#                '@JKHallATL @CameronNBeach Crazy. So with that theme, is your ER being overrun with COVID-19 patients?')]),
#  OrderedDict([('@id', '1246779094949343232'),
#               ('#text',
#                "@MTNNG @globacoms @9mobileng @AirtelNigeria please don't install the 5G in Nigeria. It's killing people in UK n CHina, it's the cause of CoronaVirus, @MBuhari @SaharaReporters @jidesanwoolu @tundefashola @oluremitinubu @ProfOsinbajo please save us all. @realDonaldTrump help us")]),
#  OrderedDict([('@id', '1246779097503711234'),
#               ('#text',
#                '#coronavirus‘a karsi modum... https://t.co/9bmvptUTjF')]),
#  OrderedDict([('@id', '1246779098120282112'),
#               ('#text',
#                'Dr Catherine Calderwood needs to resign - her position as Scotland’s Chief Medical Officer is untenable https://t.co/9mfDCjr7BD')]),
#  OrderedDict([('@id', '1253289677639073792'),
#               ('#text',
#                'This must not be allowed or condoned ANYWHERE in the world!\nSoroptimist International of Ellesmere Port and District.\nCheck us out on Facebook...SI Ellesmere Port and District\n@SoroptiTweet @SIGBI1 @CheshireLive @SIRegionCNWW @UNICEF @UN @UNGeneva https://t.co/7MR4Fz67aQ')]),
#  OrderedDict([('@id', '1253289677760626690'),
#               ('#text',
#                'And the African government are all mum about this. We need to teach the small-eyed frogs lessons #40billion #StopChinaRacism #ThursdayThoughts https://t.co/JkUkEghBHi')]),
#  OrderedDict([('@id', '1253289677794283520'),
#               ('#text',
#                "Ben Shapiro: Oil crisis amid coronavirus – for AOC and the left, it's just another political opportunity\n\nhttps://t.co/1vKKoC3VS7")]),
#  OrderedDict([('@id', '1253289678628937728'),
#               ('#text',
#                'Turkey marks its 100th year of parliament amid coronavirus https://t.co/hvs40Yau99 via @primanewss')]),
#  OrderedDict([('@id', '1253289679006437376'),
#               ('#text',
#                'Why is This Not Being Reported? Current Data Provides Support that the China Coronavirus Reacts Significantly to Sun and Heat -- Look at the Numbers from the Southern States! https://t.co/4intHmMdvh via @gatewaypundit')]),
#  OrderedDict([('@id', '1253289681334263811'),
#               ('#text',
#                'Guys this is getting thick we need to start finding better ways to make money during this period online https://t.co/PblvAoJbju      \nGet to know more about how to make money\n#40billion  #lockdownextension #CoronaVirusInNigeria https://t.co/DDIem2Zm3j')]),
#  OrderedDict([('@id', '1253289681506185216'),
#               ('#text',
#                '@Jim_Jordan @carolinadream11 I was going to vote for trump but with the Cdc working the numbers on this coronavirus and trump playing puppet to fauci.. I fear the president is no longer the one calling the shots')]),
#  OrderedDict([('@id', '1253289681942458369'),
#               ('#text',
#                '"70 percent of the patients sick enough to be admitted to the hospital did not have a fever."\n\nhttps://t.co/VqmD6pjIwY')]),
#  OrderedDict([('@id', '1253289682034741248'),
#               ('#text',
#                'If you still think this is all an over reaction, just read this https://t.co/wQBKv8mngY')]),
#  OrderedDict([('@id', '1253289682152099840'),
#               ('#text',
#                'Watch: COVID-19 clinical updates \nLectures from our COVID-19 webinar which took place last night are now available to watch online. \nOur full archive of COVID-19 updates can be found at this link. These lectures are open to all healthcare professionals.\nhttps://t.co/8I1wEHmVTC')]),
#  OrderedDict([('@id', '1253289682496098305'),
#               ('#text',
#                'UK missed coronavirus contact tracing opportunity, experts say\n\nhttps://t.co/ch7TvvxBLO')]),
#  OrderedDict([('@id', '1253289683083300864'),
#               ('#text',
#                "14 year old son of CNN's Chris Cuomo tests positive for Coronavirus just weeks after his dad and mom recovered from it., Newscastars - https://t.co/Zcr5YRKsYH https://t.co/jy3X5w11PR")]),
#  OrderedDict([('@id', '1253289683154538496'),
#               ('#text',
#                '@BillKristol @dave1oakns More liberal Fear Mongering to keep America in lockdown, This coronavirus pandemic is all about 2020 election and overthrowing the @realDonaldTrump Administration, Russia Hoax, Impeachment did not work so here we are.')]),
#  OrderedDict([('@id', '1253289683435556864'),
#               ('#text',
#                '@Reuters In China a second wave of the pandemic is being felt | 10 more people tested positive for the virus\n\nLatest updates | # cases per million population👇\n\nhttps://t.co/TqfSuF2JTF\n#COVID19 #Covid_19')]),
#  OrderedDict([('@id', '1253289683586605056'),
#               ('#text',
#                '15 Most Profitable Online Skills to Learn From Home Amid COVID-19 https://t.co/IWIX9nH3J8')]),
#  OrderedDict([('@id', '1253289685100769281'),
#               ('#text',
#                'My thoughts.\n\nWill a vaccine ever be 100% effective, against coronavirus 2019 (COVID-19)? \n\nUK. To all journalists etc.        Lockdown not ending yet. \n\n@WorldCOVID19.   COVID-19 is not your friend. https://t.co/GY5ZwJeJXh https://t.co/vGP6n4Qswi')]),
#  OrderedDict([('@id', '1253289685645918214'),
#               ('#text',
#                "@realDonaldTrump \nThat's what the devil does according to the Bible.\n#TrumpIsGodless \n#ItsAlliTsFault ⬆️ https://t.co/iQSjmJAzMG")]),
#  OrderedDict([('@id', '1253289685847179266'),
#               ('#text',
#                "Noli De Castro might have COVID19, and that's why he's not in TV Patrol. Let Alvin Elchico or Jorge Cariño take his place, or even Julius Babao.")]),
#  OrderedDict([('@id', '1253289686082125824'),
#               ('#text',
#                'Fake news. There were only 13,000 people tested yesterday. This is not news reporting it’s Tory propaganda by someone who should know better! https://t.co/WwYvEPGDhf https://t.co/UcK1qsRynx')]),
#  OrderedDict([('@id', '1253289686245822470'),
#               ('#text',
#                'The government will be able to borrow very cheaply to respond to the #coronavirus, due to low interest rates.\n\nBut raising £225 billion from gilt sales over 4 months would double the amount raised in 2009 - "£45 billion in a single month is a lot".\n\nhttps://t.co/WfIR7Yd59a https:')]),
#  OrderedDict([('@id', '1253289686400991235'),
#               ('#text', 'https://t.co/HyGJs0X00U')]),
#  OrderedDict([('@id', '1253289686849785858'),
#               ('#text',
#                "Brooo I've been ahead of the curve this whole time😌😌\n\nhttps://t.co/UpDYvi2LH2")]),
#  OrderedDict([('@id', '1253289687030140929'),
#               ('#text',
#                '#coronavirus update\n\n58 more deaths since yesterday - total of confirmed #COVID19 deaths in Scotland now 1120\n\n9049 confirmed cases - an increase of 371 since yesterday\n\n1748 people in hospital - decrease of 28 since yesterday\n\n148 in ICU - decrease of 7 https://t.co/xDb3kJ44OE')]),
#  OrderedDict([('@id', '1253289687340453889'),
#               ('#text',
#                'We’re All Grieving. This Is How We Get Through It. https://t.co/bTvKzFyxOD')]),
#  OrderedDict([('@id', '1253289687696867331'),
#               ('#text',
#                'Americas workers who refuse to return to their jobs because they are afraid about catching the coronavirus should not count on getting unemployment benefits, state officials and labor law experts say.')]),
#  OrderedDict([('@id', '1253289689634803715'),
#               ('#text',
#                "On Saturday at 1pm hear how @TristanWelch's life and work at @Parkers_Tavern  are being affected by the coronavirus. On @cambridge105 radio. https://t.co/n036IPpXW3")]),
#  OrderedDict([('@id', '1253289689819340802'),
#               ('#text',
#                '@jaketapper my aunt died in a car crash and they listed her cause of death as COVID-19 😞 can you help us please')]),
#  OrderedDict([('@id', '1253289691165724672'),
#               ('#text',
#                'The latest A Gazeta Chupim! https://t.co/Agkn4JI4JG Thanks to @Flordemariach1 #covid19 #directo')]),
#  OrderedDict([('@id', '1253289691501256704'),
#               ('#text',
#                '@WhiteHouse @realDonaldTrump A malaria drug widely touted by President Donald Trump for treating the new\xa0coronavirus\xa0showed no benefit in a large analysis of its use in U.S. veterans hospitals. There were more deaths among those given hydroxychloroquine versus standard care, researchers reported.  AP')]),
#  OrderedDict([('@id', '1253289691652091908'),
#               ('#text',
#                "Missouri Sues China for 'Sinister Campaign of Deception' That Helped Spread Coronavirus https://t.co/iqw7fy9Ugv #NewsandPolitics via @pjmedia_com")]),
#  OrderedDict([('@id', '1253289693761933312'),
#               ('#text',
#                '@Altavistagoogle https://t.co/3chcjG7f6v\nInformation is out there if you look for it. https://t.co/yiYQMPmSYr')]),
#  OrderedDict([('@id', '1253289693980090370'),
#               ('#text',
#                'Banks Gave Richest Clients ‘Concierge Treatment’ for Pandemic Aid \n\n"...some of the nation’s biggest banks, including JPMorgan @Chase, @Citibank and @usbank , prioritized the applications of their wealthiest clients before turning to other loan seekers"\n\nhttps://t.co/OLhqIpAmTS')]),
#  OrderedDict([('@id', '1253289694802194436'),
#               ('#text',
#                "I have never watched any golfing event aired on television. Ever. I'd rather play than watch. But that may change when this is aired given our complete lack of any live sports content right now https://t.co/Kz66eZwSke")]),
#  OrderedDict([('@id', '1253289695657685003'),
#               ('#text', 'Well shit https://t.co/q8iTrcvrYO')]),
#  OrderedDict([('@id', '1253289695858970624'),
#               ('#text',
#                '@NatPoliceAssoc @LawEnforcement @FBI @DHSgov\nWTF? 1st Amendment does NOT mean blocking hospitals, capitals, State /federal building DURING A NATIONAL EMERGENCY with ARMED GUNMEN! #StopTheSpread #ToServeAndProtect #COVID19 https://t.co/Efl4FQ4wn7')]),
#  OrderedDict([('@id', '1253289698149183490'),
#               ('#text',
#                'HHS Chief Alex Azar Had Aide, Former Dog Breeder, Steer Pandemic Task Force | HuffPost https://t.co/nXAl02XSmY')]),
#  OrderedDict([('@id', '1253289698996285441'),
#               ('#text',
#                'Personally I find it reprehensible at this stage of our understanding of Covid-19 that he did this. Too many of us are trying to do the right thing and stay home or work in isolation as much as we can https://t.co/WcKUeF7ZJ9')]),
#  OrderedDict([('@id', '1253289699038433281'),
#               ('#text',
#                'Covid-19 | Mkhize furious with Eastern Cape Health MEC and team, sends\xa0reinforcements https://t.co/I6ckGdTELe')]),
#  OrderedDict([('@id', '1253289700028305413'),
#               ('#text',
#                '"IF the Games can be held" is a really strong statement, especially when coming from Tokyo 2020 President.\n\nTogether with "Games cannot be delayed again" it creates quite a pessimistic mode for everyone involved https://t.co/GMaoNxzYW5')]),
#  OrderedDict([('@id', '1253289700078559234'),
#               ('#text',
#                'I knew this leader of Racists was up to something the minute he wrote that rubbish about the EFF. @GwenNgwenya khuza umuntu wakho sisi... https://t.co/wwRE81OVIX')]),
#  OrderedDict([('@id', '1253289703597576193'),
#               ('#text', 'https://t.co/zKlMvpGeQi')]),
#  OrderedDict([('@id', '1253289703710666757'),
#               ('#text',
#                '#coronavirus #stayhomesavelives #healthcare #hospitals #medical https://t.co/oaJ9W0gas7')]),
#  OrderedDict([('@id', '1253289703924695040'),
#               ('#text',
#                "Bird &amp; Bird's latest BrandWrites article: COVID-19 update: UKIPO maintains extensions of deadlines until further notice https://t.co/GFXEsGkzW2")]),
#  OrderedDict([('@id', '1253289706432978944'),
#               ('#text', 'Someone give me a rollie https://t.co/sEmppg4Otf')]),
#  OrderedDict([('@id', '1253289706881777665'),
#               ('#text',
#                'Hot Pockets heir seeks to avoid prison time, citing coronavirus https://t.co/DIz4F8SxJM via @nypost')]),
#  OrderedDict([('@id', '1253289707787649024'),
#               ('#text',
#                'Principles for return to work from @NicolaSturgeon @scotgov here 👇https://t.co/8Qb62muPwL')]),
#  OrderedDict([('@id', '1253289707850604544'),
#               ('#text',
#                "It's one more wonderful, thoughtful and unexpected gesture a school district is doing for its students during the #COVID19 pandemic.  Well done, @MasonSchools @cooperlearns!!!")]),
#  OrderedDict([('@id', '1253289708332830721'),
#               ('#text',
#                'Two cats in New York become first US pets to test positive for virus https://t.co/zorskpoWdu via @scmpnews')]),
#  OrderedDict([('@id', '1253289710572666881'),
#               ('#text',
#                '.@scotgov have published their COVID-19 framework for decision-making. Key takeaway - we’re going to have to find a new normality. Potential for staggered schooling. Some business restarts. More testing + tracing.\nhttps://t.co/RmEeF6DrHG')]),
#  OrderedDict([('@id', '1253289711319293952'),
#               ('#text', '🙏 https://t.co/DHUaKGLm73')]),
#  OrderedDict([('@id', '1253289711499698178'),
#               ('#text',
#                'Florida ice cream business isn’t so sweet with coronavirus pandemic https://t.co/lUb9osXYwl https://t.co/CBgYNZwXW0')]),
#  OrderedDict([('@id', '1253289711990378529'),
#               ('#text',
#                'Meanwhile, in Europe... https://t.co/r94s0kSI1K This is madness. It gives false hopes we have already passed the worst phase #COVID19 #StayHomeSaveLives https://t.co/PpTunYJDHA')]),
#  OrderedDict([('@id', '1253289712304795650'),
#               ('#text',
#                'Hidden Outbreaks Spread Through U.S. Cities Far Earlier Than Americans Knew, Estimates Say https://t.co/yBP0xIdXM0')]),
#  OrderedDict([('@id', '1257545203268964352'),
#               ('#text',
#                'The battle against COVID-19 may be overwhelming, but there are easy and simple things that you can do to help stop the spread of the virus. Watch this video to find out ways to keep yourself healthy during this pandemic. #WashYourHands #KeepDistance #StaySafe #Coronavirus https://t.co/nfDQIR855R')]),
#  OrderedDict([('@id', '1257545204183314436'),
#               ('#text',
#                'Surprised to see such low engagement on the post. No no. JK! I am not. https://t.co/mtSv09kWfS')]),
#  OrderedDict([('@id', '1257545204325855232'),
#               ('#text',
#                'WOW.....one day an asymptomatic person or two will show up and shed the virus on 45 and his team of idiots. https://t.co/MxN3baSjLz')]),
#  OrderedDict([('@id', '1257545205416292352'),
#               ('#text',
#                'Thought of the day #morningvibes #morningmotivation #morningthought #hardwork #hardworkpayoff #bekind #bepositive #thinkpositive #tuesdayvibes #tuesdaythought #tuesdaymotibation #tuesdayquotes #realestate #Covid19#stayshomestaysafe https://t.co/p9mXBGRtXC')]),
#  OrderedDict([('@id', '1257545205793935360'),
#               ('#text',
#                'Smokers are 80 percent less likely to severely suffer from novel #coronavirus than non-smokers, according to a French study which prompted researchers to start trials of giving nicotine patches to #COVID_19 patients, front-line workers, and citizens.\n\nhttps://t.co/QvZgpwWzc9')]),
#  OrderedDict([('@id', '1257545206141906947'),
#               ('#text',
#                'New COVID-19 Tracker Predicts Future Hot Spots Over Next 7-10 Days https://t.co/BE2z74IEXP')]),
#  OrderedDict([('@id', '1257545206406283264'),
#               ('#text',
#                '‘Prime Minister Narendra Modi is almost a superhuman’, says Australian envoy to India\nhttps://t.co/h2nR3PC8Xa via NaMo App https://t.co/PakeeCsWUK')]),
#  OrderedDict([('@id', '1257545206628417536'),
#               ('#text',
#                '@FrescoMattic Why they keep sending stuff to Vegas we can’t get rid of the stuff we have already like the raider fans coronavirus and all these damn hornets #WeFull')]),
#  OrderedDict([('@id', '1257545206666342400'),
#               ('#text',
#                '@NancyMc63977796 @IlhanMN Wish we were like Venezuela right now,  they have less than 500 covid19 cases')]),
#  OrderedDict([('@id', '1257545207781847041'),
#               ('#text',
#                '"Certain genders"...\n\nThese imbeciles could try out for Climate Barbie\'s @cathmckenna crew of fraud artists \n\nThe west needs to purge itself of these communist scum bags https://t.co/EByL0dk6fU')]),
#  OrderedDict([('@id', '1257545208410980354'),
#               ('#text',
#                "@imAakashK01 The government doesn't care about your health or family that’s why they opened Alcohol shops... they care *only* how to take your hard-earned money from you. \nAlcohol kills 2,60,000 dies every year in India....If we compared it with COVID-19 it is much higher.")]),
#  OrderedDict([('@id', '1257545208507449344'),
#               ('#text',
#                '[the day the coronavirus is finally vaccinated out of existence] thanks for watching our special presentation of "pandemic"! we now return you to your regularly scheduled crisis')]),
#  OrderedDict([('@id', '1257545208838979585'),
#               ('#text',
#                'We are going back to level 5 😒 https://t.co/zRT50pg06m')]),
#  OrderedDict([('@id', '1257545209434513409'),
#               ('#text',
#                '@IlhanMN WHERE THE HELL ARE OUR TAX REFUNDS &amp; STIMULUS CHECKS?  WHY IS THE IRS NOT WORKING?  PICK UP THE DAMN PHONES AND GET BACK TO WORK IRS!  Americans need to cut all pay to congress and Senate until the IRS is caught back up and answering phones.  STOP PAYING TAXES.  Enough! #COVID19')]),
#  OrderedDict([('@id', '1257545211577880579'),
#               ('#text',
#                "@dhscgovuk Coronavirus: France's first known case 'was in December' I am also confident I contracted the virus in December  https://t.co/LmZL94eWrT")]),
#  OrderedDict([('@id', '1257545211665842176'),
#               ('#text',
#                "@GOPLeader @realDonaldTrump Since when do you have common sense?! We're in this mess because you enable Trump whose only accomplishments are have the most COVID-19 cases and deaths in the world by far. You helped him get there. https://t.co/yZFuBu2T11")]),
#  OrderedDict([('@id', '1257545212559151105'),
#               ('#text',
#                '“We are not on a eradication policy...” until #Australia is there is no way that #NewZealand can allow or want to have a #TravelBubble between the 2 countries. The risk is too high for reintroduction of #Covid19 into the New Zealand. As a Kiwi in Aus that’s tough to hear')]),
#  OrderedDict([('@id', '1257545212978778112'),
#               ('#text',
#                '#IndiaFightsCorona\nIAF combats COVID-19\nvia NaMo App https://t.co/Ff7YzPRDmO')]),
#  OrderedDict([('@id', '1257545213083557888'),
#               ('#text',
#                "With this many dead, that ain't gonna fly. But hey, now or after January. They still go to jail. https://t.co/hynOQu35Zh")]),
#  OrderedDict([('@id', '1257545214195118081'),
#               ('#text',
#                '@briantylercohen @realDonaldTrump 😂😂😂\nhttps://t.co/Y0PqDFeq26')]),
#  OrderedDict([('@id', '1257545214274633731'),
#               ('#text',
#                '#Scientists offer nanomedicine with citrus extracts against COVID-19. #COVID19 #CoronaVirusUpdate #CoronavirusFacts #Latestresearch #Staysafe #Mustread #Submitpaper at https://t.co/dVryE4BVnm  or to Email id nanomedicine@emedicalsciences.com\n#Source: https://t.co/OePyS8uP3a')]),
#  OrderedDict([('@id', '1257545214878777347'),
#               ('#text',
#                'Stop The world. I want to get off. https://t.co/PbE7ejG25C')]),
#  OrderedDict([('@id', '1261644325898858496'),
#               ('#text',
#                'COVID-19 Special Law School Podcast\nhttps://t.co/uUQc26G8nk\n#legaleducation #lawschool #LegalTech #AI #ArtificialIntelligence  #Technology https://t.co/4CmvkFDmS5')]),
#  OrderedDict([('@id', '1261644326150471681'),
#               ('#text',
#                'Doctors want testing. \n\n@IngrahamAngle doesn’t think it’s necessary.\n\nWho do you trust?\n\n#TrustScience #TrustDoctors #COVID #coronavirus https://t.co/B312nWCvWE')]),
#  OrderedDict([('@id', '1261644326532263945'),
#               ('#text', 'Never shut down again. https://t.co/4HZndFBHJW')]),
#  OrderedDict([('@id', '1261644327056539649'),
#               ('#text',
#                'Coronavirus Deaths Are Artificially Inflated in Two Ways\nhttps://t.co/qSZNOYp8v1')]),
#  OrderedDict([('@id', '1261644328218374145'),
#               ('#text',
#                '@CntrySpectator @JoJoFromJerz @realDonaldTrump In front of the coronavirus #noconsideration #noteducated #selfish')]),
#  OrderedDict([('@id', '1261644328432283650'),
#               ('#text',
#                'Liz Weston: Coronavirus hardship withdrawal shouldn’t be subject to withholding https://t.co/Gl57Rtytqk')]),
#  OrderedDict([('@id', '1261644328969134082'),
#               ('#text',
#                '@realDonaldTrump Way to go..you are killing your base! Not smart!\nhttps://t.co/iRfAw3qpgp')]),
#  OrderedDict([('@id', '1261644329191378944'),
#               ('#text',
#                'Hundreds gather in Hyde Park in mass protest against lockdown https://t.co/zmRCVlpJPg')]),
#  OrderedDict([('@id', '1261644329459818496'),
#               ('#text',
#                'Gaslighting death: DT awards 6-month sole-source contract to private IT company to collect data on covid19 patients &amp; deaths. Decision bypassed covid task force". Alternative facts on the way en route to Nov election? @LarryDiamond #Biden2020   https://t.co/TCdxVE7TlU')]),
#  OrderedDict([('@id', '1261644329732505600'),
#               ('#text',
#                'an image which includes all types of races, sex,genders,religions,age group.......world needs to do more to end this "unequal inequality"i.e. socially created inequality https://t.co/zbmSY4VpWJ')]),
#  OrderedDict([('@id', '1261644331909214210'),
#               ('#text',
#                'Big Education Ape: DeVos Funnels Coronavirus Relief Funds to Favored Private and Religious Schools - The New York Times - https://t.co/pj218ZMUqE https://t.co/AzMoJXIhkI')]),
#  OrderedDict([('@id', '1261644332060356608'),
#               ('#text',
#                '#Italy police is blocking and menacing Italians 🇮🇹 in Rome protesting against Giuseppi illegitimate gov! Police is against WE THE PEOPLE. We need military help from the US army to free us from dictactorship @realDonaldTrump @SecPompeo @RudyGiuliani @DeAnna4Congress https://t.co/1afF4wysto')]),
#  OrderedDict([('@id', '1261644332362338305'),
#               ('#text', 'https://t.co/tNExZWmpL4')]),
#  OrderedDict([('@id', '1261644333310267393'),
#               ('#text',
#                'Sales tax relief arrives, courtesy of the coronavirus https://t.co/qSFlxz8Iia https://t.co/ZJUONbUl8v')]),
#  OrderedDict([('@id', '1261644333574500354'),
#               ('#text',
#                '@ingrampaul5 @RTUKnews Amazing coronavirus knows the 2m rule doesnt apply to the police.')]),
#  OrderedDict([('@id', '1261644333733814275'),
#               ('#text',
# ...
#  OrderedDict([('@id', '1267247106034728960'),
#               ('#text',
#                'Issues &amp; Answers: Steve Denty of Hospitality N.L. discusses the impact of COVID-19 on the tourism industry, and Natural Resources Minister Siobhan Coady discusses the sale of the Come by Chance refinery https://t.co/mL73Uz6Klw https://t.co/GpyaMoAIVU')]),
#  OrderedDict([('@id', '1267247108442243073'),
#               ('#text',
#                'some how i believe that all of this was planned out and we’re following out the plan ... now they’re adding shit to kill us off. just my theory but what do i know. https://t.co/zFTKapgBx9')]),
#  OrderedDict([('@id', '1267247109599887364'),
#               ('#text',
#                'Remember, No One Is Coming to Save Us https://t.co/mGkdtRfumj')]),
#  OrderedDict([('@id', '1267247111072034817'),
#               ('#text',
#                'Update!\nCarleton’s Black Student Alliance has set up a fund called the BSA 4-U fund supporting Black students affected by Covid-19 \nFor our followers: consider using some of your generational wealth and donate \nVenmo: bsa-2020\nPayPal: https://t.co/NpzMjXoLsF')]),
#  OrderedDict([('@id', '1267247111621533705'),
#               ('#text',
#                '#BlackLivesMatters #JusticeForGeorgeFloyd i forgot coronavirus even existed because of this movement AND IM LIVING FOR IT.JUSTICE FOR GEORGE FLOYD.  BLACK LIVES MATTER. ✊🏿✊🏾✊🏽.  SIGN THE PETITIONS&gt;&gt;&gt;.   Ways To Help https://t.co/AmC9Cmp29j')]),
#  OrderedDict([('@id', '1267247112716079105'),
#               ('#text',
#                '@thehill Sorry to break the news to you @realDonaldTrump, but it looks like Antifa (Anti-Fascists), have spread beyond our borders. You are running out of excuses, just like you did with the #CoronavirusPandemic \n\n#protests2020 #GeorgeFloydProtests')]),
#  OrderedDict([('@id', '1267247113248923649'),
#               ('#text',
#                'Coronavirus after church has closed and he sees me trying to talk with my crush https://t.co/nLuuH1iLV8')]),
#  OrderedDict([('@id', '1267247113995517960'),
#               ('#text',
#                'Impact of Covid-19 on Trawler Yachts Market: Global Industry Overview and structure analysis for 2020-2026 – Segrate Journal - https://t.co/hz4C6h1wIx...')]),
#  OrderedDict([('@id', '1248889090344435718'),
#               ('#text',
#                'This is what I’ve been wondering. The people living in nursing homes are American citizens too. They should be included by the federal government in the official death count. #trumpcovidfails #TrumpIsAnIdiot #TrumpPlague https://t.co/3HrL05toGz')]),
#  OrderedDict([('@id', '1248889092269420544'),
#               ('#text',
#                'JUST IN: Cebu Governor Gwen Garcia announced that there are 3 new confirmed cases of COVID-19 in Cebu City.\n\nThere are now 26 confirmed cases of COVID-19 in the city.\n\n#COVID19PH https://t.co/gmd0RKqsC4')]),
#  OrderedDict([('@id', '1248889093028749312'),
#               ('#text',
#                'This tweet is exactly why this country is absolutely in the bin. Hopefully this pandemic is followed by meteors https://t.co/kfPv0t9VHS')]),
#  OrderedDict([('@id', '1248889093968158721'),
#               ('#text',
#                '#climate Australian #bushfires were wake up call to the World &amp; #coronavirus is Natures way of telling us we can’t sit back &amp; take our Planet for granted. This virus is just the entree. Climate Change if not stopped will do us all in. Climates WWIII must be declared now, not wait https://t.co/2Xjb6qWAzX')]),
#  OrderedDict([('@id', '1248889094370967552'),
#               ('#text',
#                'Crowdfunding campaign  @masks4scotland launched to provide PPE to Scottish medical teams… https://t.co/mfk1Uq3kTy via @Sunday_Post #COVIDー19')]),
#  OrderedDict([('@id', '1248889094970773504'),
#               ('#text',
#                '@MhHoban @jackseale @DanSeanClayton I don’t think there’s a cover up on that specific data — it comes later, and from a different source (ONS I think), than the NHS’s Covid19 death figures. So either they delay and include those figures, and be accused of withholding, or they release incomplete numbers.')]),
#  OrderedDict([('@id', '1248889097407479809'),
#               ('#text',
#                '64\n\nCovid-19 death toll hits 100,000 globally https://t.co/DAfTP8VnmO')]),
#  OrderedDict([('@id', '1248889097726365699'),
#               ('#text',
#                'Beautiful but such sad words from a nurse in the USA @HacksCorona @coronavirus @covid19 @Oprah https://t.co/gtIF33BHXa')]),
#  OrderedDict([('@id', '1242452836782411777'),
#               ('#text',
#                "Breaking: Coronavirus unemployment payment to rise to €350 per week and Government to pay 70pc of retained workers' salaries. https://t.co/neSRCOEEob")]),
#  OrderedDict([('@id', '1242452836811767810'),
#               ('#text', 'https://t.co/CQZOzBGVBR https://t.co/Qp2qlPiB5I')]),
#  OrderedDict([('@id', '1242452836857896961'),
#               ('#text',
#                '@obyezeks These government people! Now you want to look at other countries in battling Covid19 but didn’t look at how they developed their country and made it a better place for their citizens? Shame on everyone who made this country a failed state')]),
#  OrderedDict([('@id', '1242452836883091462'),
#               ('#text',
#                "#Republicans seem incapable of shedding their proclivity to favor the pampered and the well off at the expense of everybody else.” \n#VoteRepublicansOut\n\nThe GOP's Coronavirus Bailout Would Let Trump's Hotels Get a Loan But Not Planned Parenthood https://t.co/Zl9quiCg8w")]),
#  OrderedDict([('@id', '1242452837189046273'),
#               ('#text', 'YAS! https://t.co/LHqKLHQbUt')]),
#  OrderedDict([('@id', '1242452841081569281'),
#               ('#text',
#                'Researchers at Johns Hopkins are working on a vaccine for COVID19. “...it can take 9 months to a year and a half to get to human clinical trials, which can be very difficult &amp; require a lot of resources, whether that’s philanthropic or government grants” https://t.co/AACVDP25QJ')]),
#  OrderedDict([('@id', '1242452841203142656'),
#               ('#text',
#                "@frangsant @ryanstruyk @jaketapper Because you're assuming that the U.S. has a social structure similar to Italy and Spain, and we don't.  Ours is closer to Germany's.\n\nhttps://t.co/9UKFqkNeew")]),
#  OrderedDict([('@id', '1242452841379368965'),
#               ('#text',
#                'Playing some symphonic music this morning for my littles while I try to #Workathome. Praying that they too someday will share my love of #music of all types. #CFISDLearningatHome @CFISDMusic #COVID19 \nListening to Scheherezade by Rimsky-Korsakov https://t.co/2Jgi7sAoru')]),
#  OrderedDict([('@id', '1242452841891090434'),
#               ('#text', 'https://t.co/wDxHiFZ7Zy')]),
#  OrderedDict([('@id', '1242452845233704962'),
#               ('#text',
#                '"It\'s a real threat and a lot of doctors are scared, myself included," said an LA-area doctor. \n\nDoctors and healthcare workers are concerned about their own safety, as supplies run short and coronavirus case numbers rise, @LAist @KPCC:\n\nhttps://t.co/fL7biYRg9P')]),
#  OrderedDict([('@id', '1242452845435248641'),
#               ('#text', 'https://t.co/wUBJ0y67v6')]),
#  OrderedDict([('@id', '1242452845460250628'),
#               ('#text',
#                'Want to know what a "normal" day for an ER doc looks like?\nThank you @Craig_A_Spencer for sharing this and for all that you do for your patients!  Stay well. https://t.co/ELJETl9BEE')]),
#  OrderedDict([('@id', '1242452845510553600'),
#               ('#text',
#                "Let the coronavirus be a lesson to you, Americans. You don't have to take whatever your government throws at you. The next time oligarchies refuse to help the common people, all you have to do is stay home - stay out of airplanes and businesses - and they will panic.")]),
#  OrderedDict([('@id', '1242452845821034496'),
#               ('#text',
#                'Tune in to @ABC this morning at 11am ET / 10am CT https://t.co/S6CzzwRI8o')]),
#  OrderedDict([('@id', '1242452845821153280'),
#               ('#text',
#                'Thank you Harris County!\n#StayAtHomeOrder #Texas #Houston #Houstonlockdown #COVID19 https://t.co/lrABunRv3c')]),
#  OrderedDict([('@id', '1242452849549811712'),
#               ('#text',
#                "Don't you remember NAGGIN Nancy's rule.\nYou've got to pass a bill  before you can find out what's in it.\nThe dems want authoritarian power and they want to force forward their agenda https://t.co/H4d0dURmCC")]),
#  OrderedDict([('@id', '1242452849554006016'),
#               ('#text',
#                '@DailyMailUK They and Morgan clearly believe that coronavirus can’t cross those invisible walls they built in that 6 feet of space between them.')]),
#  OrderedDict([('@id', '1242452849621110789'),
#               ('#text',
#                '#LockdownNow save Life 🙏 @NC_Governor https://t.co/PO7hwWlMAL')]),
#  OrderedDict([('@id', '1242452849948266497'),
#               ('#text',
#                'We need the comic relief.  Wonder who will be briefing him on current events? https://t.co/KUPa2ZS3zd')]),
#  OrderedDict([('@id', '1242452850116091904'),
#               ('#text',
#                "Israel's Chief Rabbi calls for public fast day amid coronavirus outbreak https://t.co/e5M7zxfLeN")]),
#  OrderedDict([('@id', '1242452850220957701'),
#               ('#text',
#                'Ibuprofen may increase susceptibility to the coronavirus, new study says; experts also link infectious complications to its use – https://t.co/z5y4RDkYsK https://t.co/QdF68p7rzE')]),
#  OrderedDict([('@id', '1242452853345615875'),
#               ('#text',
#                'Live updates: How is #coronavirus affecting the global #rail sector? What measures are #railway organisations across the globe taking in response to the impact of the recent #COVID19 outbreak? https://t.co/PF5sJ2N4BF https://t.co/2SVRnpcPSS')]),
#  OrderedDict([('@id', '1242452853731594240'),
#               ('#text',
#                'If @realDonaldTrump and his band of flunkies choose to attempt to “reopen” the country for “business,” whatever that means, then we will be on our own. The rest of the world won’t touch us. They will have or will be fighting their own war against #coronavirus . We will be alone.')]),
#  OrderedDict([('@id', '1242452853958086656'),
#               ('#text', 'Oh ? https://t.co/CDwsKQGE2v')]),
#  OrderedDict([('@id', '1242452854029324291'),
#               ('#text',
#                'still confused about what a lockdown means? i made it easy: \n\nhttps://t.co/SvHwiifY48')]),
#  OrderedDict([('@id', '1242452857762308096'),
#               ('#text',
#                'ALEX PURVIS —\xa0Coronavirus Business Insurance Q&amp;A: Policyholder coverage counsel on developing insurance issues\nhttps://t.co/OYXrHZPjpC https://t.co/m9yxrO12TM')]),
#  OrderedDict([('@id', '1242452857942618112'),
#               ('#text',
#                'HOLY. FUCKING. SHIT.\n\nTrump Won’t Order Vital Coronavirus Supplies Because Corporate CEOs Asked Him Not To | Vanity Fair https://t.co/nFBbOdFBL2')]),
#  OrderedDict([('@id', '1242452858072641538'),
#               ('#text',
#                '@itvnews Capitalism is killing Mother Earth https://t.co/LvUZsHqErI')]),
#  OrderedDict([('@id', '1242452858106081280'),
#               ('#text',
#                'TEXAS - Lt. Gov. Dan Patrick said Monday the country should go back to work in the face of the #coronavirus pandemic. \nhttps://t.co/FUYHdD6HNc')]),
#  OrderedDict([('@id', '1242452858114629634'),
#               ('#text',
#                '"top coronavirus response official in Italy, the country with the highest death toll, attributed two successive declines in the daily death rate to a national lockdown that appeared to be finally bearing fruit\\\\')]),
#  OrderedDict([('@id', '1242452858169106437'),
#               ('#text', 'coronavirus pare agora https://t.co/mOTnYyAhGx')]),
#  OrderedDict([('@id', '1242452858190077953'),
#               ('#text',
#                '@RIBAWestMids and @bimstore We Are OPEN for Business.\nWith regards to our current unfortunate situation of social distancing and working from home as much as possible, we want to reassure you that Cubicle Centre are adhering to this and following guidelines.  #COVID19 https://t.co/WQNRFJLK2e')]),
#  OrderedDict([('@id', '1242452858533867520'),
#               ('#text',
#                '@stingdas I’m getting forwards from red pilled whack jobs blazing coronavirus on Bill Gates. It’s always Bill Gates for these theorists 😂')]),
#  OrderedDict([('@id', '1242452861751111682'),
#               ('#text',
#                'I call BS!!! DO NOT VOTE FOR THIS CRAP THAT HAS NOTHING TO DO WITH THE #ChineseCoronaVirus! Democrats are #EnemyOfThePeople @SenateGOP @SenatorLankford @JimInhofe @realDonaldTrump @GOPChairwoman @GOP @senatemajldr @GOPLeader  @OneLastRun54 @SpeakerPelosi https://t.co/BLPrt0nZfr')]),
#  OrderedDict([('@id', '1242452861864345600'),
#               ('#text',
#                '1 death and 205 new cases of coronavirus confirmed, bringing the total number of cases to 767 #saudiarabia #health #epidemic https://t.co/cOSwj3lB7N https://t.co/OF5aHGPfU5')]),
#  OrderedDict([('@id', '1242452862065618945'),
#               ('#text',
#                'LORD, Please Heal The  World🌈\n\n#PrayforITALY 🇮🇹#PrayfortheWORLD🌐 #CoronaVirusPandemic🦠 https://t.co/GM9E0pEkW1')]),
#  OrderedDict([('@id', '1242452862086647808'),
#               ('#text',
#                'Unlike car accidents, #coronavirus cases — and, therefore, deaths — can expand exponentially. The sheer scale of the problem means that people will die waiting for a bed or waiting to be triaged. https://t.co/EhG66Uzc1A')]),
#  OrderedDict([('@id', '1242452862132723712'),
#               ('#text',
#                '@ChuckCallesto It’s all about the dramatic effects. She revels in showing she has the power and she knows her final scene is coming. Stick to Chinese Coronavirus issues.')]),
#  OrderedDict([('@id', '1242452862279565312'),
#               ('#text',
#                ". @MayorBetsyPrice - if we don't slow spread of virus, we could easily exceed our hospital bed capacity   #COVID19")]),
#  OrderedDict([('@id', '1242452862438977536'),
#               ('#text', 'https://t.co/YNArvtmk9n')]),
#  OrderedDict([('@id', '1242452862451560448'),
#               ('#text',
#                'Bill Gates Calls For National Tracking System For Coronavirus https://t.co/EeeEpUOodY')]),
#  OrderedDict([('@id', '1242452862564732928'),
#               ('#text',
#                "LA Galaxy's Javier Hernández (Chicharito) derided for Amazon complaint amid coronavirus crisis\n#COVID19 \nhttps://t.co/Xwkj9HHMHI")]),
#  OrderedDict([('@id', '1242452866498998272'),
#               ('#text',
#                'Many of you have been asking about the effectiveness of #IAQ solutions on #COVID19. We have put together an FAQ to help you have informed conversations with customers on cutting down airborne transmission. Read more: https://t.co/bNYzqj1gsi #Resideo #HVAC https://t.co/PooWMQerno')]),
#  OrderedDict([('@id', '1242452866507423744'),
#               ('#text',
#                "Where the hell is this hanta virus from ? Plz the world is already going through alot .....we don't want any hanta or hunter virus 😠 https://t.co/n9C3M6xaCc")]),
#  OrderedDict([('@id', '1242452866683547650'),
#               ('#text',
#                'Great Article - the grief over expectations is real. https://t.co/aTukuoLbqZ')]),
#  OrderedDict([('@id', '1242452866746527744'),
#               ('#text', 'https://t.co/yMBxmgWOG1')]),
#  OrderedDict([('@id', '1242452866830225408'),
#               ('#text',
#                'France to tighten coronavirus lockdown | NHK WORLD-JAPAN News https://t.co/k46wyFMZ7p')]),
#  OrderedDict([('@id', '1242030551063621633'),
#               ('#text',
#                '.@fayedsouza , any jokes about this ? https://t.co/cT8tgaqgHz')]),
#  ...]

# %% [markdown]
# Here we are successfully able to parse through the XML file

# %% [markdown]
# ### Summary  <a class="anchor" name="sum"></a>
#
# Here in this task the main task was to convert the raw text into proper XML text format.
#
# The first and main task involved in this is to extract the tweets, ID and the dates using Regex
#
# The regex used were: -
#
#
# id  - '"id":"([0-9]+)"'
#
# tweet - "text":(.*?)(?:"id":|"created_at":|"errors":)
#
# created - "created_at":"(\d{4}-\d{2}-\d{2})(?:.*?)"
#
# The tweets were also stripped by the charecters ',{}]'
#
# The tweets and id was converted to dictionary res for further processing
#
# Characters & , ' , " , > , < are to be converted to the HTML Codes.
#
# Then the tweets which are non - english are removed.
#
# Finally we write the tweets and id into XML file as per the xml sample file

# %% [markdown]
# ####
